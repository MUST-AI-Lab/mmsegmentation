# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_r5-d16_640x640_DML_160k_camvid.py'  
#--options model.backbone.with_cp=True
# Out:
# 2022-03-18 14:29:28,198 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 10.2
# ...

# %%
import os
# !python tools/test.py 'configs/unet/fcn_unet_r5-d16_640x640_DML_160k_camvid.py' \
'work_dirs/fcn_unet_r5-d16_640x640_DML_160k_camvid/latest.pth' --eval 'mIoU' 'mDice' 'mFscore'
# Out:
# 2022-03-19 20:38:53,143 - mmseg - INFO - Loaded 101 images
# Use load_from_local loader
# 0
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 101/101, 7.0 task/s, elapsed: 14s, ETA:     0sper class results:
#
# +-------------+-------+-------+-------+--------+-----------+--------+
# |    Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +-------------+-------+-------+-------+--------+-----------+--------+
# |     void    | 14.96 | 39.38 | 26.02 | 26.02  |   19.43   | 39.38  |
# |     sky     | 94.42 | 97.23 | 97.13 | 97.13  |   97.03   | 97.23  |
# |   building  | 84.76 | 87.31 | 91.75 | 91.75  |   96.67   | 87.31  |
# | column_pole | 21.65 | 30.83 |  35.6 |  35.6  |   42.11   | 30.83  |
# |     road    | 96.76 |  98.3 | 98.35 | 98.35  |    98.4   |  98.3  |
# |   sidewalk  | 87.52 | 94.77 | 93.34 | 93.34  |   91.96   | 94.77  |
# |     tree    | 88.93 | 98.07 | 94.14 | 94.14  |   90.51   | 98.07  |
# | sing_symbol |  66.1 | 73.13 | 79.59 | 79.59  |   87.31   | 73.13  |
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/unet/fcn_unet_r5-d16_640x640_DML_160k_camvid.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2022-03-25 13:26:24,367 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/unet/fcn_unet_r5-d16_640x640_CPS_160k_camvid.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2022-03-24 11:42:43,301 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
os.environ['OMP_NUM_THREADS']="16"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/unet/fcn_unet_r5-d16_256x256_DML-triple_80k_camvid_noAux_dist.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# 2022-05-01 17:59:45,855 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (GCC) 7.4.0
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
# ...
