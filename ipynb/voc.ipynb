# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
os.environ['OMP_NUM_THREADS']="16"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/unet/fcn_unet_s5-d16_512x512_40k_dist_voc12.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# 2022-04-27 21:14:05,181 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (GCC) 7.4.0
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
# ...

# %%
import os
# !python tools/test.py 'configs/unet/fcn_unet_s5-d16_512x512_40k_dist_voc12.py' \
'work_dirs/fcn_unet_s5-d16_512x512_40k_dist_voc12/iter_4000.pth' --eval 'mIoU' 'mDice' 'mFscore'
# Out:
# 2022-04-27 21:08:15,721 - mmseg - INFO - Loaded 1449 images
# Use load_from_local loader
# 0
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1449/1449, 6.0 task/s, elapsed: 241s, ETA:     0sper class results:
#
# +-------------+-------+-------+-------+--------+-----------+--------+
# |    Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +-------------+-------+-------+-------+--------+-----------+--------+
# |  background | 73.47 | 99.84 | 84.71 | 84.71  |   73.56   | 99.84  |
# |  aeroplane  |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |   bicycle   |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |     bird    |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |     boat    |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |    bottle   |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |     bus     |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# |     car     |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
os.environ['OMP_NUM_THREADS']="16"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/deeplabv3/deeplabv3_r50-d8_512x512_40k_voc12.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# 2022-04-28 12:47:19,628 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (GCC) 7.4.0
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
# ...
