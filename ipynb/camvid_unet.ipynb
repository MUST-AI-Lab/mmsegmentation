# %% [markdown]
# # Train Unet on CamVid dataset
# ### *Make sure to prepare the dataset before running the following code, if not, go to the "camvid_deeplab.ipynb" file.

# %%
cd /disk1/zzl/mmsegmentation
# Out:
# /disk1/zzl/mmsegmentation

# %%
import sys
sys.path.insert(0,'/disk1/zzl/mmsegmentation/')
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh '/disk1/zzl/mmsegmentation/configs/unet/fcn_unet_r5-d16_640x640_80k_camvid.py' 2
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2021-10-25 17:28:06,324 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.8 (default, Apr 13 2021, 19:58:26) [GCC 7.3.0]
# CUDA available: True
# GPU 0,1: TITAN Xp
# CUDA_HOME: /usr/local/cuda-9.2
# NVCC: Cuda compilation tools, release 9.2, V9.2.88
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.10) 5.4.0 20160609
# PyTorch: 1.7.1+cu92
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
# ...
