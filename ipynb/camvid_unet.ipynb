# %% [markdown]
# # Train Unet on CamVid dataset
# ### *Make sure to prepare the dataset before running the following code, if not, go to the "camvid_deeplab.ipynb" file.

# %%
cd /disk1/zzl/mmsegmentation
# Out:
# /disk1/zzl/mmsegmentation

# %%
import sys
sys.path.insert(0,'/disk1/zzl/mmsegmentation/')
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh '/disk1/zzl/mmsegmentation/configs/unet/fcn_unet_r5-d16_640x640_80k_camvid.py' 2
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2021-10-25 17:28:06,324 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.8 (default, Apr 13 2021, 19:58:26) [GCC 7.3.0]
# CUDA available: True
# GPU 0,1: TITAN Xp
# CUDA_HOME: /usr/local/cuda-9.2
# NVCC: Cuda compilation tools, release 9.2, V9.2.88
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.10) 5.4.0 20160609
# PyTorch: 1.7.1+cu92
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.2-Product Build 20210312 for Intel(R) 64 architecture applications
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_r5-d16_640x640_CPS_160k_camvid.py'  
#--options model.backbone.with_cp=True
# Out:
# 2022-03-16 17:39:27,111 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 10.2
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/test.py 'configs/unet/fcn_unet_r5-d16_640x640_CPS_160k_camvid.py'\
'work_dirs/fcn_unet_r5-d16_640x640_CPS_160k_camvid/latest.pth'\
--eval "mIoU" "mFscore" "mDice" --gpu-id 1 
#--eval 'auc' "mFscore" "mDice" "mAcc"BlockingIOError
# Out:
# 2022-03-18 13:14:13,662 - mmseg - INFO - Loaded 101 images
# Use load_from_local loader
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 101/101, 6.3 task/s, elapsed: 16s, ETA:     0sper class results:
#
# +-------------+-------+-------+--------+-----------+--------+-------+
# |    Class    |  IoU  |  Acc  | Fscore | Precision | Recall |  Dice |
# +-------------+-------+-------+--------+-----------+--------+-------+
# |     void    | 14.52 | 36.67 | 25.36  |   19.38   | 36.67  | 25.36 |
# |     sky     | 94.38 | 97.35 | 97.11  |   96.87   | 97.35  | 97.11 |
# |   building  |  86.9 | 89.61 | 92.99  |   96.64   | 89.61  | 92.99 |
# | column_pole | 22.32 | 30.04 |  36.5  |   46.49   | 30.04  |  36.5 |
# |     road    | 97.05 | 98.24 |  98.5  |   98.77   | 98.24  |  98.5 |
# |   sidewalk  | 89.13 | 95.52 | 94.25  |   93.01   | 95.52  | 94.25 |
# |     tree    | 90.29 | 98.05 |  94.9  |   91.94   | 98.05  |  94.9 |
# | sing_symbol |  68.3 | 73.33 | 81.17  |   90.88   | 73.33  | 81.17 |
# ...

# %% [markdown]
# ## Camvid->Unet 1 gpu only

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_r5-d16_640x640_160k_camvid.py' --gpu-ids 1 
#--options model.backbone.with_cp=True
# Out:
# 2022-03-08 16:07:39,869 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 10.2
# ...

# %%
# Out:
# # conda environments:
# #
# base                     /disk1/anaconda3
# mmclass                  /home/zzl/.conda/envs/mmclass
# yolov5                   /home/zzl/.conda/envs/yolov5
# zzl1                  *  /home/zzl/.conda/envs/zzl1
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda info
# Out:
#      active environment : zzl1
#     active env location : /home/zzl/.conda/envs/zzl1
#             shell level : 3
#        user config file : /home/zzl/.condarc
#  populated config files :
#           conda version : 4.8.3
#     conda-build version : 3.18.11
#          python version : 3.8.3.final.0
#        virtual packages : __cuda=11.0
#                           __glibc=2.23
#        base environment : /disk1/anaconda3  (read only)
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /disk1/anaconda3/pkgs
#                           /home/zzl/.conda/pkgs
#        envs directories : /home/zzl/.conda/envs
#                           /disk1/anaconda3/envs
#                platform : linux-64
# ...

# %%
# !pip install mmcv-full==1.3.13 -f https://download.openmmlab.com/mmcv/dist/cu102/torch1.10.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu102/torch1.10.0/index.html
# ...
#   Using cached mmcv_full-1.3.13-cp38-cp38-linux_x86_64.whl
# ...
#   Attempting uninstall: mmcv-full
#     Found existing installation: mmcv-full 1.4.2
#     Uninstalling mmcv-full-1.4.2:
#       Successfully uninstalled mmcv-full-1.4.2
# ...

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
os.environ['CUDA_VISIBLE_DEVICES']="0,1"
os.environ['OMP_NUM_THREADS']="16"
# !/disk1/zzl/mmsegmentation/tools/dist_train.sh 'configs/unet/fcn_unet_r5-d16_256x256_80k_camvid_noAux_dist.py' 2
# Out:
# /home/zzl/.local/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# 2022-04-30 16:40:35,908 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (GCC) 7.4.0
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
# ...
