# %% [markdown]
# ## DRIVE's official website did not provide a test-set-annotation, so, as adviced by MMSegmentation, we need to download it from other people's Baidu Cloud.
# + link: https://pan.baidu.com/s/1UpQtbhgtVdlqc0QGbESx3A

# %% [markdown]
# ## Then, we need to unzip it, and pack "test", "train" folder into zip, so that they are compatible with drive.py script

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation/data/DRIVE')
# !unzip DRIVE.zip
os.chdir('/disk1/zzl/mmsegmentation/data/DRIVE/DRIVE')
# !zip -r test test
# !zip -r training training
# Out:
# Archive:  DRIVE.zip
# replace DRIVE/test/1st_manual/12_manual1.gif? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
#   adding: test/ (stored 0%)
#   adding: test/2nd_manual/ (stored 0%)
#   adding: test/2nd_manual/13_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/17_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/12_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/14_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/19_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/09_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/03_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/04_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/20_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/02_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/06_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/11_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/16_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/18_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/15_manual2.gif (deflated 2%)
#   adding: test/2nd_manual/10_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/08_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/01_manual2.gif (deflated 1%)
#   adding: test/2nd_manual/07_manual2.gif (deflated 2%)
#   adding: test/2nd_manual/05_manual2.gif (deflated 1%)
#   adding: test/images/ (stored 0%)
#   adding: test/images/13_test.tif (deflated 2%)
#   adding: test/images/02_test.tif (deflated 2%)
#   adding: test/images/19_test.tif (deflated 3%)
#   adding: test/images/04_test.tif (deflated 3%)
#   adding: test/images/09_test.tif (deflated 2%)
#   adding: test/images/15_test.tif (deflated 3%)
#   adding: test/images/01_test.tif (deflated 2%)
#   adding: test/images/14_test.tif (deflated 2%)
#   adding: test/images/11_test.tif (deflated 2%)
#   adding: test/images/07_test.tif (deflated 3%)
#   adding: test/images/12_test.tif (deflated 2%)
#   adding: test/images/05_test.tif (deflated 2%)
#   adding: test/images/08_test.tif (deflated 2%)
#   adding: test/images/20_test.tif (deflated 2%)
#   adding: test/images/17_test.tif (deflated 2%)
#   adding: test/images/03_test.tif (deflated 3%)
#   adding: test/images/10_test.tif (deflated 3%)
#   adding: test/images/06_test.tif (deflated 2%)
#   adding: test/images/18_test.tif (deflated 2%)
#   adding: test/images/16_test.tif (deflated 2%)
#   adding: test/mask/ (stored 0%)
#   adding: test/mask/18_test_mask.gif (stored 0%)
#   adding: test/mask/05_test_mask.gif (stored 0%)
#   adding: test/mask/03_test_mask.gif (stored 0%)
#   adding: test/mask/06_test_mask.gif (stored 0%)
#   adding: test/mask/10_test_mask.gif (stored 0%)
#   adding: test/mask/02_test_mask.gif (stored 0%)
#   adding: test/mask/20_test_mask.gif (stored 0%)
#   adding: test/mask/14_test_mask.gif (stored 0%)
#   adding: test/mask/12_test_mask.gif (stored 0%)
#   adding: test/mask/07_test_mask.gif (stored 0%)
#   adding: test/mask/15_test_mask.gif (stored 0%)
#   adding: test/mask/01_test_mask.gif (stored 0%)
#   adding: test/mask/17_test_mask.gif (stored 0%)
#   adding: test/mask/04_test_mask.gif (stored 0%)
#   adding: test/mask/11_test_mask.gif (stored 0%)
#   adding: test/mask/08_test_mask.gif (stored 0%)
#   adding: test/mask/13_test_mask.gif (stored 0%)
#   adding: test/mask/19_test_mask.gif (stored 0%)
#   adding: test/mask/16_test_mask.gif (stored 0%)
#   adding: test/mask/09_test_mask.gif (stored 0%)
#   adding: test/1st_manual/ (stored 0%)
#   adding: test/1st_manual/01_manual1.gif (stored 0%)
#   adding: test/1st_manual/11_manual1.gif (stored 0%)
#   adding: test/1st_manual/16_manual1.gif (stored 0%)
#   adding: test/1st_manual/03_manual1.gif (stored 0%)
#   adding: test/1st_manual/09_manual1.gif (stored 0%)
#   adding: test/1st_manual/02_manual1.gif (stored 0%)
#   adding: test/1st_manual/13_manual1.gif (stored 0%)
#   adding: test/1st_manual/10_manual1.gif (stored 0%)
#   adding: test/1st_manual/18_manual1.gif (stored 0%)
#   adding: test/1st_manual/19_manual1.gif (stored 0%)
#   adding: test/1st_manual/04_manual1.gif (stored 0%)
#   adding: test/1st_manual/12_manual1.gif (stored 0%)
#   adding: test/1st_manual/07_manual1.gif (stored 0%)
#   adding: test/1st_manual/06_manual1.gif (stored 0%)
#   adding: test/1st_manual/17_manual1.gif (stored 0%)
#   adding: test/1st_manual/14_manual1.gif (stored 0%)
#   adding: test/1st_manual/15_manual1.gif (stored 0%)
#   adding: test/1st_manual/05_manual1.gif (stored 0%)
#   adding: test/1st_manual/20_manual1.gif (stored 0%)
#   adding: test/1st_manual/08_manual1.gif (stored 0%)
#   adding: training/ (stored 0%)
#   adding: training/images/ (stored 0%)
#   adding: training/images/25_training.tif (deflated 2%)
#   adding: training/images/24_training.tif (deflated 2%)
#   adding: training/images/33_training.tif (deflated 2%)
#   adding: training/images/27_training.tif (deflated 2%)
#   adding: training/images/29_training.tif (deflated 3%)
#   adding: training/images/31_training.tif (deflated 2%)
#   adding: training/images/23_training.tif (deflated 1%)
#   adding: training/images/26_training.tif (deflated 3%)
#   adding: training/images/32_training.tif (deflated 2%)
#   adding: training/images/37_training.tif (deflated 3%)
#   adding: training/images/34_training.tif (deflated 4%)
#   adding: training/images/35_training.tif (deflated 3%)
#   adding: training/images/21_training.tif (deflated 2%)
#   adding: training/images/30_training.tif (deflated 3%)
#   adding: training/images/39_training.tif (deflated 3%)
#   adding: training/images/22_training.tif (deflated 2%)
#   adding: training/images/36_training.tif (deflated 3%)
#   adding: training/images/38_training.tif (deflated 2%)
#   adding: training/images/28_training.tif (deflated 3%)
#   adding: training/images/40_training.tif (deflated 3%)
#   adding: training/mask/ (stored 0%)
#   adding: training/mask/31_training_mask.gif (stored 0%)
#   adding: training/mask/39_training_mask.gif (stored 0%)
#   adding: training/mask/26_training_mask.gif (stored 0%)
#   adding: training/mask/30_training_mask.gif (stored 0%)
#   adding: training/mask/38_training_mask.gif (stored 0%)
#   adding: training/mask/28_training_mask.gif (stored 0%)
#   adding: training/mask/27_training_mask.gif (stored 0%)
#   adding: training/mask/32_training_mask.gif (stored 0%)
#   adding: training/mask/25_training_mask.gif (stored 0%)
#   adding: training/mask/40_training_mask.gif (stored 0%)
#   adding: training/mask/21_training_mask.gif (stored 0%)
#   adding: training/mask/22_training_mask.gif (stored 0%)
#   adding: training/mask/37_training_mask.gif (stored 0%)
#   adding: training/mask/36_training_mask.gif (stored 0%)
#   adding: training/mask/34_training_mask.gif (stored 0%)
#   adding: training/mask/33_training_mask.gif (stored 0%)
#   adding: training/mask/23_training_mask.gif (stored 0%)
#   adding: training/mask/29_training_mask.gif (stored 0%)
#   adding: training/mask/24_training_mask.gif (stored 0%)
#   adding: training/mask/35_training_mask.gif (stored 0%)
#   adding: training/1st_manual/ (stored 0%)
#   adding: training/1st_manual/32_manual1.gif (stored 0%)
#   adding: training/1st_manual/26_manual1.gif (stored 0%)
#   adding: training/1st_manual/38_manual1.gif (stored 0%)
#   adding: training/1st_manual/30_manual1.gif (stored 0%)
#   adding: training/1st_manual/33_manual1.gif (stored 0%)
#   adding: training/1st_manual/39_manual1.gif (stored 0%)
#   adding: training/1st_manual/25_manual1.gif (stored 0%)
#   adding: training/1st_manual/37_manual1.gif (stored 0%)
#   adding: training/1st_manual/29_manual1.gif (stored 0%)
#   adding: training/1st_manual/21_manual1.gif (stored 0%)
#   adding: training/1st_manual/40_manual1.gif (stored 0%)
#   adding: training/1st_manual/36_manual1.gif (stored 0%)
#   adding: training/1st_manual/22_manual1.gif (stored 0%)
#   adding: training/1st_manual/24_manual1.gif (stored 0%)
#   adding: training/1st_manual/34_manual1.gif (stored 0%)
#   adding: training/1st_manual/27_manual1.gif (stored 0%)
#   adding: training/1st_manual/35_manual1.gif (stored 0%)
#   adding: training/1st_manual/28_manual1.gif (stored 0%)
#   adding: training/1st_manual/23_manual1.gif (stored 0%)
#   adding: training/1st_manual/31_manual1.gif (stored 0%)

# %%
os.chdir('/disk1/zzl/mmsegmentation/data')
# !mv DRIVE/DRIVE/* ./

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/convert_datasets/drive.py 'data/training.zip' 'data/test.zip'
# Out:
# Making directories...
# Extracting training.zip...
# Generating training dataset...
# Extracting test.zip...
# Generating validation dataset...
# Removing the temporary files...
# Done!

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_s5-d16_64x64_40k_drive.py' --gpu-ids 1
# Out:
# 2022-02-27 20:08:24,394 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce GTX 1080 Ti
# CUDA_HOME: :/disk1/zzl/cuda-10.2:/home/zzl/cuda-10.2
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.9.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.9.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.10.0
# OpenCV: 4.5.5
# MMCV: 1.3.13
# MMCV Compiler: GCC 7.3
# MMCV CUDA Compiler: 10.2
# MMSegmentation: 0.17.0+ce5fcc3
# ------------------------------------------------------------
#
# 2022-02-27 20:08:24,395 - mmseg - INFO - Distributed training: False
# 2022-02-27 20:08:24,643 - mmseg - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# model = dict(
#     type='EncoderDecoder',
#     pretrained=None,
#     backbone=dict(
#         type='UNet',
#         in_channels=3,
#         base_channels=64,
#         num_stages=5,
#         strides=(1, 1, 1, 1, 1),
#         enc_num_convs=(2, 2, 2, 2, 2),
#         dec_num_convs=(2, 2, 2, 2),
#         downsamples=(True, True, True, True),
#         enc_dilations=(1, 1, 1, 1, 1),
#         dec_dilations=(1, 1, 1, 1),
#         with_cp=False,
#         conv_cfg=None,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         act_cfg=dict(type='ReLU'),
#         upsample_cfg=dict(type='InterpConv'),
#         norm_eval=False),
#     decode_head=dict(
#         type='FCNHead',
#         in_channels=64,
#         in_index=4,
#         channels=64,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=128,
#         in_index=3,
#         channels=64,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(64, 64), stride=(42, 42)))
# dataset_type = 'DRIVEDataset'
# data_root = 'data/DRIVE'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# img_scale = (584, 565)
# crop_size = (64, 64)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', img_scale=(584, 565), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(584, 565),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=4,
#     workers_per_gpu=4,
#     train=dict(
#         type='RepeatDataset',
#         times=40000,
#         dataset=dict(
#             type='DRIVEDataset',
#             data_root='data/DRIVE',
#             img_dir='images/training',
#             ann_dir='annotations/training',
#             pipeline=[
#                 dict(type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations'),
#                 dict(
#                     type='Resize',
#                     img_scale=(584, 565),
#                     ratio_range=(0.5, 2.0)),
#                 dict(
#                     type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#                 dict(type='RandomFlip', prob=0.5),
#                 dict(type='PhotoMetricDistortion'),
#                 dict(
#                     type='Normalize',
#                     mean=[123.675, 116.28, 103.53],
#                     std=[58.395, 57.12, 57.375],
#                     to_rgb=True),
#                 dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#                 dict(type='DefaultFormatBundle'),
#                 dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#             ])),
#     val=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50,
#     hooks=[
#         dict(type='TextLoggerHook', by_epoch=False),
#         dict(type='TensorboardLoggerHook')
#     ])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='IterBasedRunner', max_iters=40000)
# checkpoint_config = dict(by_epoch=False, interval=4000)
# evaluation = dict(
#     interval=4000, metric=['mDice', 'mIoU', 'mFscore'], pre_eval=True)
# work_dir = './work_dirs/fcn_unet_s5-d16_64x64_40k_drive'
# gpu_ids = [1]
#
# 2022-02-27 20:08:24,964 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-02-27 20:08:25,174 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-02-27 20:08:25,175 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:147: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   warnings.warn(
# 2022-02-27 20:08:25,177 - mmseg - INFO - EncoderDecoder(
#   (backbone): UNet(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (4): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#   (decode_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss()
#     (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss()
#     (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )
# 2022-02-27 20:08:25,179 - mmseg - INFO - Loaded 20 images
# 2022-02-27 20:08:28,936 - mmseg - INFO - Loaded 20 images
# 2022-02-27 20:08:28,937 - mmseg - INFO - Start running, host: zzl@ubuntu-MW51-HP0-00, work_dir: /disk1/zzl/mmsegmentation/work_dirs/fcn_unet_s5-d16_64x64_40k_drive
# 2022-02-27 20:08:28,937 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-02-27 20:08:28,937 - mmseg - INFO - workflow: [('train', 1)], max: 40000 iters
# /home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2022-02-27 20:08:31,516 - mmseg - INFO - Iter [50/40000]	lr: 9.989e-03, eta: 0:30:45, time: 0.046, data_time: 0.003, memory: 4588, decode.loss_seg: 0.5227, decode.acc_seg: 78.3384, aux.loss_seg: 0.2132, aux.acc_seg: 77.8348, loss: 0.7359
# 2022-02-27 20:08:32,758 - mmseg - INFO - Iter [100/40000]	lr: 9.978e-03, eta: 0:23:35, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.4848, decode.acc_seg: 79.5050, aux.loss_seg: 0.1997, aux.acc_seg: 79.3678, loss: 0.6844
# 2022-02-27 20:08:34,009 - mmseg - INFO - Iter [150/40000]	lr: 9.967e-03, eta: 0:21:15, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.4671, decode.acc_seg: 79.8030, aux.loss_seg: 0.1953, aux.acc_seg: 78.8646, loss: 0.6625
# 2022-02-27 20:08:35,276 - mmseg - INFO - Iter [200/40000]	lr: 9.956e-03, eta: 0:20:07, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.4325, decode.acc_seg: 82.1321, aux.loss_seg: 0.1775, aux.acc_seg: 81.4686, loss: 0.6100
# 2022-02-27 20:08:36,535 - mmseg - INFO - Iter [250/40000]	lr: 9.945e-03, eta: 0:19:24, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3976, decode.acc_seg: 83.3473, aux.loss_seg: 0.1686, aux.acc_seg: 81.7697, loss: 0.5662
# 2022-02-27 20:08:37,794 - mmseg - INFO - Iter [300/40000]	lr: 9.933e-03, eta: 0:18:55, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.4107, decode.acc_seg: 82.6606, aux.loss_seg: 0.1651, aux.acc_seg: 82.2136, loss: 0.5758
# 2022-02-27 20:08:39,042 - mmseg - INFO - Iter [350/40000]	lr: 9.922e-03, eta: 0:18:33, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3657, decode.acc_seg: 84.8057, aux.loss_seg: 0.1513, aux.acc_seg: 84.1488, loss: 0.5171
# 2022-02-27 20:08:40,280 - mmseg - INFO - Iter [400/40000]	lr: 9.911e-03, eta: 0:18:15, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3380, decode.acc_seg: 86.2388, aux.loss_seg: 0.1418, aux.acc_seg: 85.2592, loss: 0.4799
# 2022-02-27 20:08:41,515 - mmseg - INFO - Iter [450/40000]	lr: 9.900e-03, eta: 0:18:01, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3458, decode.acc_seg: 85.8866, aux.loss_seg: 0.1438, aux.acc_seg: 85.4241, loss: 0.4896
# 2022-02-27 20:08:42,772 - mmseg - INFO - Iter [500/40000]	lr: 9.889e-03, eta: 0:17:51, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3078, decode.acc_seg: 87.5652, aux.loss_seg: 0.1269, aux.acc_seg: 87.0464, loss: 0.4347
# 2022-02-27 20:08:44,004 - mmseg - INFO - Iter [550/40000]	lr: 9.878e-03, eta: 0:17:41, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3307, decode.acc_seg: 86.7739, aux.loss_seg: 0.1366, aux.acc_seg: 86.1412, loss: 0.4673
# 2022-02-27 20:08:45,246 - mmseg - INFO - Iter [600/40000]	lr: 9.866e-03, eta: 0:17:32, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3175, decode.acc_seg: 87.1857, aux.loss_seg: 0.1321, aux.acc_seg: 86.6595, loss: 0.4496
# 2022-02-27 20:08:46,495 - mmseg - INFO - Iter [650/40000]	lr: 9.855e-03, eta: 0:17:26, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3089, decode.acc_seg: 87.7703, aux.loss_seg: 0.1284, aux.acc_seg: 87.0424, loss: 0.4373
# 2022-02-27 20:08:47,733 - mmseg - INFO - Iter [700/40000]	lr: 9.844e-03, eta: 0:17:19, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3117, decode.acc_seg: 87.5674, aux.loss_seg: 0.1290, aux.acc_seg: 87.0333, loss: 0.4406
# 2022-02-27 20:08:48,977 - mmseg - INFO - Iter [750/40000]	lr: 9.833e-03, eta: 0:17:14, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.2945, decode.acc_seg: 87.9817, aux.loss_seg: 0.1219, aux.acc_seg: 87.4620, loss: 0.4164
# 2022-02-27 20:08:50,231 - mmseg - INFO - Iter [800/40000]	lr: 9.822e-03, eta: 0:17:09, time: 0.025, data_time: 0.001, memory: 4588, decode.loss_seg: 0.3074, decode.acc_seg: 87.5897, aux.loss_seg: 0.1243, aux.acc_seg: 87.3691, loss: 0.4316
# ^C
# Traceback (most recent call last):
#   File "tools/train.py", line 183, in <module>
#     main()
#   File "tools/train.py", line 172, in main
#     train_segmentor(
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/knockknock/email_sender.py", line 55, in wrapper_sender
#     value = func(*args, **kwargs)
#   File "/disk1/zzl/mmsegmentation/mmseg/apis/train.py", line 121, in train_segmentor
#     runner.run(data_loaders, cfg.workflow)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/iter_based_runner.py", line 133, in run
#     iter_runner(iter_loaders[i], **kwargs)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/iter_based_runner.py", line 60, in train
#     outputs = self.model.train_step(data_batch, self.optimizer, **kwargs)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/parallel/data_parallel.py", line 67, in train_step
#     return self.module.train_step(*inputs[0], **kwargs[0])
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/base.py", line 139, in train_step
#     loss, log_vars = self._parse_losses(losses)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/base.py", line 190, in _parse_losses
#     log_vars[loss_name] = loss_value.item()
# KeyboardInterrupt

# %%
# !python tools/test.py 'configs/unet/fcn_unet_s5-d16_64x64_40k_drive.py' \
'work_dirs/fcn_unet_s5-d16_64x64_40k_drive/iter_24000.pth' --eval 'auc'
# Out:
# 2022-03-04 11:00:41,077 - mmseg - INFO - Loaded 20 images
# Use load_from_local loader
# ^C
# Traceback (most recent call last):
#   File "tools/test.py", line 234, in <module>
#     main()
#   File "tools/test.py", line 141, in main
#     checkpoint = load_checkpoint(model, args.checkpoint, map_location='cpu')
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/checkpoint.py", line 513, in load_checkpoint
#     checkpoint = _load_checkpoint(filename, map_location, logger)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/checkpoint.py", line 451, in _load_checkpoint
#     return CheckpointLoader.load_checkpoint(filename, map_location, logger)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/checkpoint.py", line 244, in load_checkpoint
#     return checkpoint_loader(filename, map_location)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/checkpoint.py", line 261, in load_from_local
#     checkpoint = torch.load(filename, map_location=map_location)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/serialization.py", line 607, in load
#     return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/serialization.py", line 882, in _load
#     result = unpickler.load()
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/serialization.py", line 857, in persistent_load
#     load_tensor(data_type, size, key, _maybe_decode_ascii(location))
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/serialization.py", line 845, in load_tensor
#     storage = zip_file.get_storage_from_record(name, size, dtype).storage()
# KeyboardInterrupt

# %% [markdown]
# ## Now, add CPS (supervised only)

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_s5-d16_64x64_CPS_40k_drive.py' --gpu-ids 0
#--options model.backbone.with_cp=True
# Out:
# 2022-03-18 17:01:55,068 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.11.3+cu102
# OpenCV: 4.5.5
# MMCV: 1.3.13
# MMCV Compiler: GCC 5.4
# MMCV CUDA Compiler: 10.2
# MMSegmentation: 0.17.0+ce5fcc3
# ------------------------------------------------------------
#
# 2022-03-18 17:01:55,069 - mmseg - INFO - Distributed training: False
# 2022-03-18 17:01:55,330 - mmseg - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# model = dict(
#     type='CPSsupervised',
#     train_cfg=dict(unsup_weight=1),
#     test_cfg=dict(inference_on='branch1'),
#     model=dict(
#         type='EncoderDecoder',
#         pretrained=None,
#         backbone=dict(
#             type='UNet',
#             in_channels=3,
#             base_channels=64,
#             num_stages=5,
#             strides=(1, 1, 1, 1, 1),
#             enc_num_convs=(2, 2, 2, 2, 2),
#             dec_num_convs=(2, 2, 2, 2),
#             downsamples=(True, True, True, True),
#             enc_dilations=(1, 1, 1, 1, 1),
#             dec_dilations=(1, 1, 1, 1),
#             with_cp=False,
#             conv_cfg=None,
#             norm_cfg=dict(type='BN', requires_grad=True),
#             act_cfg=dict(type='ReLU'),
#             upsample_cfg=dict(type='InterpConv'),
#             norm_eval=False),
#         decode_head=dict(
#             type='FCNHead',
#             in_channels=64,
#             in_index=4,
#             channels=64,
#             num_convs=1,
#             concat_input=False,
#             dropout_ratio=0.1,
#             num_classes=2,
#             norm_cfg=dict(type='BN', requires_grad=True),
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#         train_cfg=dict(),
#         test_cfg=dict(mode='slide', crop_size=(64, 64), stride=(42, 42))))
# dataset_type = 'DRIVEDataset'
# data_root = 'data/DRIVE'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# img_scale = (584, 565)
# crop_size = (64, 64)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', img_scale=(584, 565), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(584, 565),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=4,
#     workers_per_gpu=4,
#     train=dict(
#         type='RepeatDataset',
#         times=40000,
#         dataset=dict(
#             type='DRIVEDataset',
#             data_root='data/DRIVE',
#             img_dir='images/training',
#             ann_dir='annotations/training',
#             pipeline=[
#                 dict(type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations'),
#                 dict(
#                     type='Resize',
#                     img_scale=(584, 565),
#                     ratio_range=(0.5, 2.0)),
#                 dict(
#                     type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#                 dict(type='RandomFlip', prob=0.5),
#                 dict(type='PhotoMetricDistortion'),
#                 dict(
#                     type='Normalize',
#                     mean=[123.675, 116.28, 103.53],
#                     std=[58.395, 57.12, 57.375],
#                     to_rgb=True),
#                 dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#                 dict(type='DefaultFormatBundle'),
#                 dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#             ])),
#     val=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50,
#     hooks=[
#         dict(type='TextLoggerHook', by_epoch=False),
#         dict(type='TensorboardLoggerHook')
#     ])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='IterBasedRunner', max_iters=40000)
# checkpoint_config = dict(by_epoch=False, interval=4000)
# evaluation = dict(
#     interval=4000, metric=['mDice', 'mIoU', 'mFscore'], pre_eval=True)
# work_dir = './work_dirs/fcn_unet_s5-d16_64x64_CPS_40k_drive'
# gpu_ids = [0]
#
# 2022-03-18 17:01:55,968 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-03-18 17:01:56,169 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-03-18 17:01:56,179 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-03-18 17:01:56,369 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:147: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   warnings.warn(
# 2022-03-18 17:01:56,371 - mmseg - INFO - CPSsupervised(
#   (branch1): EncoderDecoder(
#     (backbone): UNet(
#       (encoder): ModuleList(
#         (0): Sequential(
#           (0): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (4): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#     (decode_head): FCNHead(
#       input_transform=None, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss()
#       (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#       (dropout): Dropout2d(p=0.1, inplace=False)
#       (convs): Sequential(
#         (0): ConvModule(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   )
#   (branch2): EncoderDecoder(
#     (backbone): UNet(
#       (encoder): ModuleList(
#         (0): Sequential(
#           (0): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (4): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#     (decode_head): FCNHead(
#       input_transform=None, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss()
#       (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#       (dropout): Dropout2d(p=0.1, inplace=False)
#       (convs): Sequential(
#         (0): ConvModule(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   )
#   (criterion): CrossEntropyLoss()
# )
# 2022-03-18 17:01:56,375 - mmseg - INFO - Loaded 20 images
# 2022-03-18 17:01:59,020 - mmseg - INFO - Loaded 20 images
# 2022-03-18 17:01:59,020 - mmseg - INFO - Start running, host: zzl@ubuntu-MW51-HP0-00, work_dir: /disk1/zzl/mmsegmentation/work_dirs/fcn_unet_s5-d16_64x64_CPS_40k_drive
# 2022-03-18 17:01:59,020 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-03-18 17:01:59,021 - mmseg - INFO - workflow: [('train', 1)], max: 40000 iters
# 2022-03-18 17:02:02,592 - mmseg - INFO - Iter [50/40000]	lr: 9.989e-03, eta: 0:44:02, time: 0.066, data_time: 0.003, memory: 4825, unsup_loss1: 0.1550, unsup_loss2: 0.1596, sup_loss1: 0.6142, sup_loss2: 0.6136, loss: 1.5424
# 2022-03-18 17:02:04,949 - mmseg - INFO - Iter [100/40000]	lr: 9.978e-03, eta: 0:37:37, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1157, unsup_loss2: 0.1173, sup_loss1: 0.5497, sup_loss2: 0.5602, loss: 1.3429
# 2022-03-18 17:02:07,324 - mmseg - INFO - Iter [150/40000]	lr: 9.967e-03, eta: 0:35:33, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1274, unsup_loss2: 0.1262, sup_loss1: 0.5196, sup_loss2: 0.5246, loss: 1.2977
# 2022-03-18 17:02:09,700 - mmseg - INFO - Iter [200/40000]	lr: 9.956e-03, eta: 0:34:31, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1135, unsup_loss2: 0.1137, sup_loss1: 0.4747, sup_loss2: 0.4661, loss: 1.1679
# 2022-03-18 17:02:12,063 - mmseg - INFO - Iter [250/40000]	lr: 9.945e-03, eta: 0:33:51, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1184, unsup_loss2: 0.1188, sup_loss1: 0.4595, sup_loss2: 0.4606, loss: 1.1573
# 2022-03-18 17:02:14,425 - mmseg - INFO - Iter [300/40000]	lr: 9.933e-03, eta: 0:33:23, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1083, unsup_loss2: 0.1092, sup_loss1: 0.4295, sup_loss2: 0.4322, loss: 1.0792
# 2022-03-18 17:02:16,786 - mmseg - INFO - Iter [350/40000]	lr: 9.922e-03, eta: 0:33:01, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1390, unsup_loss2: 0.1377, sup_loss1: 0.4309, sup_loss2: 0.4294, loss: 1.1371
# 2022-03-18 17:02:19,155 - mmseg - INFO - Iter [400/40000]	lr: 9.911e-03, eta: 0:32:46, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1800, unsup_loss2: 0.1826, sup_loss1: 0.3990, sup_loss2: 0.4036, loss: 1.1652
# 2022-03-18 17:02:21,530 - mmseg - INFO - Iter [450/40000]	lr: 9.900e-03, eta: 0:32:34, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1638, unsup_loss2: 0.1655, sup_loss1: 0.3827, sup_loss2: 0.3822, loss: 1.0942
# 2022-03-18 17:02:23,905 - mmseg - INFO - Iter [500/40000]	lr: 9.889e-03, eta: 0:32:24, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.1643, unsup_loss2: 0.1627, sup_loss1: 0.3782, sup_loss2: 0.3834, loss: 1.0887
# 2022-03-18 17:02:26,265 - mmseg - INFO - Iter [550/40000]	lr: 9.878e-03, eta: 0:32:14, time: 0.047, data_time: 0.002, memory: 4825, unsup_loss1: 0.
time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.0955, unsup_loss2: 0.0960, sup_loss1: 0.2507, sup_loss2: 0.2576, loss: 0.6998
# 2022-03-18 17:03:30,793 - mmseg - INFO - Iter [1900/40000]	lr: 9.576e-03, eta: 0:30:34, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1046, unsup_loss2: 0.1049, sup_loss1: 0.2667, sup_loss2: 0.2685, loss: 0.7447
# 2022-03-18 17:03:33,207 - mmseg - INFO - Iter [1950/40000]	lr: 9.565e-03, eta: 0:30:32, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1087, unsup_loss2: 0.1082, sup_loss1: 0.2845, sup_loss2: 0.2814, loss: 0.7827
# 2022-03-18 17:03:35,607 - mmseg - INFO - Exp name: fcn_unet_s5-d16_64x64_CPS_40k_drive.py
# 2022-03-18 17:03:35,607 - mmseg - INFO - Iter [2000/40000]	lr: 9.554e-03, eta: 0:30:29, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1006, unsup_loss2: 0.1003, sup_loss1: 0.2530, sup_loss2: 0.2511, loss: 0.7051
# 2022-03-18 17:03:38,022 - mmseg - INFO - Iter [2050/40000]	lr: 9.542e-03, eta: 0:30:27, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1072, unsup_loss2: 0.1074, sup_loss1: 0.2657, sup_loss2: 0.2652, loss: 0.7455
# 2022-03-18 17:03:40,448 - mmseg - INFO - Iter [2100/40000]	lr: 9.531e-03, eta: 0:30:25, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.0940, unsup_loss2: 0.0950, sup_loss1: 0.2539, sup_loss2: 0.2607, loss: 0.7036
# 2022-03-18 17:03:42,868 - mmseg - INFO - Iter [2150/40000]	lr: 9.520e-03, eta: 0:30:23, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1012, unsup_loss2: 0.1004, sup_loss1: 0.2548, sup_loss2: 0.2551, loss: 0.7115
# 2022-03-18 17:03:45,293 - mmseg - INFO - Iter [2200/40000]	lr: 9.509e-03, eta: 0:30:21, time: 0.049, data_time: 0.002, memory: 4825, unsup_loss1: 0.1078, unsup_loss2: 0.1061, sup_loss1: 0.2727, sup_loss2: 0.2733, loss: 0.7599
# 2022-03-18 17:03:47,699 - mmseg - INFO - Iter [2250/40000]	lr: 9.498e-03, eta: 0:30:18, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.1032, unsup_loss2: 0.1034, sup_loss1: 0.2659, sup_loss2: 0.2667, loss: 0.7391
# 2022-03-18 17:03:50,099 - mmseg - INFO - Iter [2300/40000]	lr: 9.486e-03, eta: 0:30:16, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.0974, unsup_loss2: 0.0989, sup_loss1: 0.2520, sup_loss2: 0.2539, loss: 0.7022
# 2022-03-18 17:03:52,523 - mmseg - INFO - Iter [2350/40000]	lr: 9.475e-03, eta: 0:30:13, time: 0.048, data_time: 0.002, memory: 4825, unsup_loss1: 0.0968, unsup_loss2: 0.0968, sup_loss1: 0.2474, sup_loss2: 0.2511, loss: 0.6922
# 2022-03-18 17:03:54,962 - mmseg - INFO - Iter [2400/40000]	lr: 9.464e-03, eta: 0:30:11, time: 0.049, data_time: 0.002, memory: 4825, unsup_loss1: 0.0967, unsup_loss2: 0.0957, sup_loss1: 0.2644, sup_loss2: 0.2636, loss: 0.7204
# 2022-03-18 17:03:57,389 - mmseg - INFO - Iter [2450/40000]	lr: 9.453e-03, eta: 0:30:09, time: 0.049, data_time: 0.002, memory: 4825, unsup_loss1: 0.1023, unsup_loss2: 0.1036, sup_loss1: 0.2688, sup_loss2: 0.2738, loss: 0.7485
# 2022-03-18 17:03:59,845 - mmseg - INFO - Iter [2500/40000]	lr: 9.442e-03, eta: 0:30:08, time: 0.049, data_time: 0.002, memory: 4825, unsup_loss1: 0
time: 0.049, data_time: 0.002, memory: 5042, unsup_loss1: 0.0469, unsup_loss2: 0.0467, sup_loss1: 0.1465, sup_loss2: 0.1468, loss: 0.3869
# 2022-03-18 17:36:23,507 - mmseg - INFO - Iter [39650/40000]	lr: 2.395e-04, eta: 0:00:18, time: 0.048, data_time: 0.002, memory: 5042, unsup_loss1: 0.0482, unsup_loss2: 0.0476, sup_loss1: 0.1500, sup_loss2: 0.1521, loss: 0.3979
# 2022-03-18 17:36:25,988 - mmseg - INFO - Iter [39700/40000]	lr: 2.215e-04, eta: 0:00:15, time: 0.050, data_time: 0.002, memory: 5042, unsup_loss1: 0.0469, unsup_loss2: 0.0471, sup_loss1: 0.1514, sup_loss2: 0.1516, loss: 0.3971
# 2022-03-18 17:36:28,453 - mmseg - INFO - Iter [39750/40000]	lr: 2.032e-04, eta: 0:00:13, time: 0.049, data_time: 0.002, memory: 5042, unsup_loss1: 0.0491, unsup_loss2: 0.0490, sup_loss1: 0.1625, sup_loss2: 0.1611, loss: 0.4216
# 2022-03-18 17:36:30,884 - mmseg - INFO - Iter [39800/40000]	lr: 1.845e-04, eta: 0:00:10, time: 0.049, data_time: 0.002, memory: 5042, unsup_loss1: 0.0505, unsup_loss2: 0.0506, sup_loss1: 0.1558, sup_loss2: 0.1554, loss: 0.4123
# 2022-03-18 17:36:33,297 - mmseg - INFO - Iter [39850/40000]	lr: 1.653e-04, eta: 0:00:07, time: 0.048, data_time: 0.002, memory: 5042, unsup_loss1: 0.0476, unsup_loss2: 0.0475, sup_loss1: 0.1466, sup_loss2: 0.1462, loss: 0.3877
# 2022-03-18 17:36:35,758 - mmseg - INFO - Iter [39900/40000]	lr: 1.455e-04, eta: 0:00:05, time: 0.049, data_time: 0.001, memory: 5042, unsup_loss1: 0.0458, unsup_loss2: 0.0455, sup_loss1: 0.1419, sup_loss2: 0.1429, loss: 0.3760
# 2022-03-18 17:36:38,225 - mmseg - INFO - Iter [39950/40000]	lr: 1.246e-04, eta: 0:00:02, time: 0.049, data_time: 0.002, memory: 5042, unsup_loss1: 0.0479, unsup_loss2: 0.0479, sup_loss1: 0.1489, sup_loss2: 0.1498, loss: 0.3945
# 2022-03-18 17:36:40,674 - mmseg - INFO - Saving checkpoint at 40000 iterations
# 2022-03-18 17:36:41,303 - mmseg - INFO - Exp name: fcn_unet_s5-d16_64x64_CPS_40k_drive.py
# 2022-03-18 17:36:41,304 - mmseg - INFO - Iter [40000/40000]	lr: 1.007e-04, eta: 0:00:00, time: 0.062, data_time: 0.002, memory: 5042, unsup_loss1: 0.0511, unsup_loss2: 0.0515, sup_loss1: 0.1629, sup_loss2: 0.1624, loss: 0.4279
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 20/20, 1.5 task/s, elapsed: 13s, ETA:     0s2022-03-18 17:36:54,644 - mmseg - INFO - per class results:
# 2022-03-18 17:36:54,645 - mmseg - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  Dice |  Acc  |  IoU  | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  98.1 | 98.75 | 96.28 |  98.1  |   97.46   | 98.75  |
# |   vessel   | 78.63 | 73.23 | 64.79 | 78.63  |    84.9   | 73.23  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 2022-03-18 17:36:54,645 - mmseg - INFO - Summary:
# 2022-03-18 17:36:54,645 - mmseg - INFO -
# +-------+-------+-------+-------+---------+------------+---------+
# |  aAcc | mDice |  mAcc |  mIoU | mFscore | mPrecision | mRecall |
# +-------+-------+-------+-------+---------+------------+---------+
# | 96.51 | 88.37 | 85.99 | 80.53 |  88.37  |   91.18    |  85.99  |
# +-------+-------+-------+-------+---------+------------+---------+
# 2022-03-18 17:36:54,645 - mmseg - INFO - Exp name: fcn_unet_s5-d16_64x64_CPS_40k_drive.py
# 2022-03-18 17:36:54,646 - mmseg - INFO - Iter(val) [20]	aAcc: 0.9651, mDice: 0.8837, mAcc: 0.8599, mIoU: 0.8053, mFscore: 0.8837, mPrecision: 0.9118, mRecall: 0.8599, Dice.background: 0.9810, Dice.vessel: 0.7863, Acc.background: 0.9875, Acc.vessel: 0.7323, IoU.background: 0.9628, IoU.vessel: 0.6479, Fscore.background: 0.9810, Fscore.vessel: 0.7863, Precision.background: 0.9746, Precision.vessel: 0.8490, Recall.background: 0.9875, Recall.vessel: 0.7323

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
# !python tools/test.py 'configs/unet/fcn_unet_s5-d16_64x64_CPS_40k_drive.py' \
'work_dirs/fcn_unet_s5-d16_64x64_CPS_40k_drive/latest.pth' --eval 'mIoU' 'mDice' 'mFscore' --gpu-id 0
# Out:
# 2022-03-18 17:58:33,370 - mmseg - INFO - Loaded 20 images
# Use load_from_local loader
# 0
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 20/20, 1.6 task/s, elapsed: 13s, ETA:     0sper class results:
#
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 96.28 | 98.76 | 98.11 | 98.11  |   97.46   | 98.76  |
# |   vessel   |  64.8 | 73.14 | 78.64 | 78.64  |   85.04   | 73.14  |
# +------------+-------+-------+-------+--------+-----------+--------+
# Summary:
#
# +-------+-------+-------+-------+---------+------------+---------+
# |  aAcc |  mIoU |  mAcc | mDice | mFscore | mPrecision | mRecall |
# +-------+-------+-------+-------+---------+------------+---------+
# | 96.52 | 80.54 | 85.95 | 88.37 |  88.37  |   91.25    |  85.95  |
# +-------+-------+-------+-------+---------+------------+---------+

# %% [markdown]
# ## Now, try and use DML

# %%
import os
#os.environ['CUDA_VISIBLE_DEVICES']='1'
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_s5-d16_64x64_DML_40k_drive.py' --gpu-ids 0
#--options model.backbone.with_cp=True
# Out:
# 2022-03-20 13:37:46,841 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0: GeForce GTX 1080 Ti
# CUDA_HOME: /home/zzl/cuda-10.2
# NVCC: Cuda compilation tools, release 10.2, V10.2.89
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.10.2+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.11.3+cu102
# OpenCV: 4.5.5
# MMCV: 1.3.13
# MMCV Compiler: GCC 5.4
# MMCV CUDA Compiler: 10.2
# MMSegmentation: 0.17.0+3c0b40c
# ------------------------------------------------------------
#
# 2022-03-20 13:37:46,842 - mmseg - INFO - Distributed training: False
# 2022-03-20 13:37:47,088 - mmseg - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# model = dict(
#     type='DML',
#     train_cfg=dict(unsup_weight=0.5),
#     test_cfg=dict(inference_on='branch1'),
#     model=dict(
#         type='EncoderDecoder',
#         pretrained=None,
#         backbone=dict(
#             type='UNet',
#             in_channels=3,
#             base_channels=64,
#             num_stages=5,
#             strides=(1, 1, 1, 1, 1),
#             enc_num_convs=(2, 2, 2, 2, 2),
#             dec_num_convs=(2, 2, 2, 2),
#             downsamples=(True, True, True, True),
#             enc_dilations=(1, 1, 1, 1, 1),
#             dec_dilations=(1, 1, 1, 1),
#             with_cp=False,
#             conv_cfg=None,
#             norm_cfg=dict(type='BN', requires_grad=True),
#             act_cfg=dict(type='ReLU'),
#             upsample_cfg=dict(type='InterpConv'),
#             norm_eval=False),
#         decode_head=dict(
#             type='FCNHead',
#             in_channels=64,
#             in_index=4,
#             channels=64,
#             num_convs=1,
#             concat_input=False,
#             dropout_ratio=0.1,
#             num_classes=2,
#             norm_cfg=dict(type='BN', requires_grad=True),
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#         train_cfg=dict(),
#         test_cfg=dict(mode='slide', crop_size=(64, 64), stride=(42, 42))))
# dataset_type = 'DRIVEDataset'
# data_root = 'data/DRIVE'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# img_scale = (584, 565)
# crop_size = (64, 64)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', img_scale=(584, 565), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(584, 565),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=8,
#     workers_per_gpu=4,
#     train=dict(
#         type='RepeatDataset',
#         times=40000,
#         dataset=dict(
#             type='DRIVEDataset',
#             data_root='data/DRIVE',
#             img_dir='images/training',
#             ann_dir='annotations/training',
#             pipeline=[
#                 dict(type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations'),
#                 dict(
#                     type='Resize',
#                     img_scale=(584, 565),
#                     ratio_range=(0.5, 2.0)),
#                 dict(
#                     type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#                 dict(type='RandomFlip', prob=0.5),
#                 dict(type='PhotoMetricDistortion'),
#                 dict(
#                     type='Normalize',
#                     mean=[123.675, 116.28, 103.53],
#                     std=[58.395, 57.12, 57.375],
#                     to_rgb=True),
#                 dict(type='Pad', size=(64, 64), pad_val=0, seg_pad_val=255),
#                 dict(type='DefaultFormatBundle'),
#                 dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#             ])),
#     val=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='DRIVEDataset',
#         data_root='data/DRIVE',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(584, 565),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50,
#     hooks=[
#         dict(type='TextLoggerHook', by_epoch=False),
#         dict(type='TensorboardLoggerHook')
#     ])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.005, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='IterBasedRunner', max_iters=40000)
# checkpoint_config = dict(by_epoch=False, interval=4000)
# evaluation = dict(
#     interval=4000, metric=['mDice', 'mIoU', 'mFscore'], pre_eval=True)
# work_dir = './work_dirs/fcn_unet_s5-d16_64x64_DML_40k_drive'
# gpu_ids = [0]
#
# 2022-03-20 13:37:47,703 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-03-20 13:37:47,867 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-03-20 13:37:47,876 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-03-20 13:37:48,041 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:147: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   warnings.warn(
# 2022-03-20 13:37:48,043 - mmseg - INFO - DML(
#   (branch1): EncoderDecoder(
#     (backbone): UNet(
#       (encoder): ModuleList(
#         (0): Sequential(
#           (0): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (4): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#     (decode_head): FCNHead(
#       input_transform=None, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss()
#       (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#       (dropout): Dropout2d(p=0.1, inplace=False)
#       (convs): Sequential(
#         (0): ConvModule(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   )
#   (branch2): EncoderDecoder(
#     (backbone): UNet(
#       (encoder): ModuleList(
#         (0): Sequential(
#           (0): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (4): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (2): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): UpConvBlock(
#           (conv_block): BasicConvBlock(
#             (convs): Sequential(
#               (0): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#               (1): ConvModule(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#           (upsample): InterpConv(
#             (interp_upsample): Sequential(
#               (0): Upsample()
#               (1): ConvModule(
#                 (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activate): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#     (decode_head): FCNHead(
#       input_transform=None, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss()
#       (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#       (dropout): Dropout2d(p=0.1, inplace=False)
#       (convs): Sequential(
#         (0): ConvModule(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   )
#   (criterion): KLDivergence()
# )
# 2022-03-20 13:37:48,048 - mmseg - INFO - Loaded 20 images
# 2022-03-20 13:37:50,313 - mmseg - INFO - Loaded 20 images
# 2022-03-20 13:37:50,313 - mmseg - INFO - Start running, host: zzl@ubuntu-MW51-HP0-00, work_dir: /disk1/zzl/mmsegmentation/work_dirs/fcn_unet_s5-d16_64x64_DML_40k_drive
# 2022-03-20 13:37:50,314 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-03-20 13:37:50,314 - mmseg - INFO - workflow: [('train', 1)], max: 40000 iters
# kl:
# tensor(8.2531, device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(8.2763, device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(4.1266, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(4.1381, device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(4.1266, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(4.1381, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(0.6944, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(0.6765, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(15508.3789, device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(15949.3984, device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(7754.1895, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(7974.6992, device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(7754.1895, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(7974.6992, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(1.0731, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(3.0062, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(inf, device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(inf, device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(inf, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(inf, device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(inf, device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(inf, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(20.9428, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(4.6476, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# tensor(0., device='cuda:0', grad_fn=<DivBackward0>)
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>)}
# {'unsup_loss1': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'unsup_loss2': tensor(0., device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss1': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>), 'sup_loss2': tensor(nan, device='cuda:0', grad_fn=<MulBackward0>)}
# kl:
# ^C
# Traceback (most recent call last):
#   File "tools/train.py", line 183, in <module>
#     main()
#   File "tools/train.py", line 172, in main
#     train_segmentor(
#   File "/disk1/zzl/mmsegmentation/mmseg/apis/train.py", line 121, in train_segmentor
#     runner.run(data_loaders, cfg.workflow)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/iter_based_runner.py", line 133, in run
#     iter_runner(iter_loaders[i], **kwargs)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/iter_based_runner.py", line 60, in train
#     outputs = self.model.train_step(data_batch, self.optimizer, **kwargs)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/parallel/data_parallel.py", line 67, in train_step
#     return self.module.train_step(*inputs[0], **kwargs[0])
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/base.py", line 138, in train_step
#     losses = self(**data_batch)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/mmcv/runner/fp16_utils.py", line 98, in new_func
#     return old_func(*args, **kwargs)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/base.py", line 108, in forward
#     return self.forward_train(img, img_metas, **kwargs)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/DML.py", line 51, in forward_train
#     log_vars_cps = self._forward_DML_train(pred_1, pred_2)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/DML.py", line 70, in _forward_DML_train
#     loss['unsup_loss1'] = weighted_loss(self._loss(self.branch1, pred_1.log(), label2, True), self.unsup_weight)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/segmentors/DML.py", line 81, in _loss
#     loss = self.criterion(pred, label, ignore_index=self.ignore_index)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/disk1/zzl/mmsegmentation/mmseg/models/losses/kl_divergence.py", line 72, in forward
#     loss_cls = self.loss_weight * self.cls_criterion(
#   File "/disk1/zzl/mmsegmentation/mmseg/models/losses/kl_divergence.py", line 21, in kl_divergence
#     print(loss)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/_tensor.py", line 249, in __repr__
#     return torch._tensor_str._str(self)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/_tensor_str.py", line 415, in _str
#     return _str_intern(self)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/_tensor_str.py", line 390, in _str_intern
#     tensor_str = _tensor_str(self, indent)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/_tensor_str.py", line 251, in _tensor_str
#     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#   File "/home/zzl/.local/lib/python3.8/site-packages/torch/_tensor_str.py", line 90, in __init__
#     nonzero_finite_vals = torch.masked_select(tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0))
# KeyboardInterrupt

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
# !python tools/test.py 'configs/unet/fcn_unet_s5-d16_64x64_DML_40k_drive.py' \
'work_dirs/fcn_unet_s5-d16_64x64_DML_40k_drive/latest.pth' --eval 'mIoU' 'mDice' 'mFscore' --gpu-id 0
# Out:
# 2022-03-18 19:22:52,594 - mmseg - INFO - Loaded 20 images
# Use load_from_local loader
# 0
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 20/20, 1.5 task/s, elapsed: 13s, ETA:     0sper class results:
#
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 96.24 | 98.77 | 98.08 | 98.08  |    97.4   | 98.77  |
# |   vessel   | 64.34 | 72.57 |  78.3 |  78.3  |   85.02   | 72.57  |
# +------------+-------+-------+-------+--------+-----------+--------+
# Summary:
#
# +-------+-------+-------+-------+---------+------------+---------+
# |  aAcc |  mIoU |  mAcc | mDice | mFscore | mPrecision | mRecall |
# +-------+-------+-------+-------+---------+------------+---------+
# | 96.48 | 80.29 | 85.67 | 88.19 |  88.19  |   91.21    |  85.67  |
# +-------+-------+-------+-------+---------+------------+---------+
