# %%
import os
os.chdir('/disk1/zzl/mmsegmentation/data')
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/healthy.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma_manualsegm.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy_manualsegm.zip'
# !wget 'https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/healthy_manualsegm.zip'
# Out:
# --2022-02-24 14:48:32--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/healthy.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19295899 (18M) [application/zip]
# Saving to: ‘healthy.zip’
#
# healthy.zip         100%[===================>]  18.40M  4.93MB/s    in 3.7s
#
# 2022-02-24 14:48:38 (4.93 MB/s) - ‘healthy.zip’ saved [19295899/19295899]
#
# --2022-02-24 14:48:38--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21732825 (21M) [application/zip]
# Saving to: ‘glaucoma.zip’
#
# glaucoma.zip        100%[===================>]  20.73M  5.32MB/s    in 3.9s
#
# 2022-02-24 14:48:43 (5.32 MB/s) - ‘glaucoma.zip’ saved [21732825/21732825]
#
# --2022-02-24 14:48:43--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29249219 (28M) [application/zip]
# Saving to: ‘diabetic_retinopathy.zip’
#
# diabetic_retinopath 100%[===================>]  27.89M  8.38MB/s    in 4.6s
#
# 2022-02-24 14:48:49 (6.12 MB/s) - ‘diabetic_retinopathy.zip’ saved [29249219/29249219]
#
# --2022-02-24 14:48:49--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29249219 (28M) [application/zip]
# Saving to: ‘diabetic_retinopathy.zip.1’
#
# diabetic_retinopath 100%[===================>]  27.89M  8.13MB/s    in 4.7s
#
# 2022-02-24 14:48:55 (5.89 MB/s) - ‘diabetic_retinopathy.zip.1’ saved [29249219/29249219]
#
# --2022-02-24 14:48:55--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma_manualsegm.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1608242 (1.5M) [application/zip]
# Saving to: ‘glaucoma_manualsegm.zip’
#
# glaucoma_manualsegm 100%[===================>]   1.53M   966KB/s    in 1.6s
#
# 2022-02-24 14:48:58 (966 KB/s) - ‘glaucoma_manualsegm.zip’ saved [1608242/1608242]
#
# --2022-02-24 14:48:59--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy_manualsegm.zip
# Resolving www5.cs.fau.de (www5.cs.fau.de)... 131.188.35.25
# Connecting to www5.cs.fau.de (www5.cs.fau.de)|131.188.35.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1524938 (1.5M) [application/zip]
# Saving to: ‘diabetic_retinopathy_manualsegm.zip’
#
# diabetic_retinopath 100%[===================>]   1.45M   876KB/s    in 1.7s
#
# 2022-02-24 14:49:01 (876 KB/s) - ‘diabetic_retinopathy_manualsegm.zip’ saved [1524938/1524938]

# %%
# !python ../tools/convert_datasets/hrf.py 'healthy.zip' 'healthy_manualsegm.zip' 'glaucoma.zip' 'glaucoma_manualsegm.zip' 'diabetic_retinopathy.zip' \
'diabetic_retinopathy_manualsegm.zip'
# Out:
# Making directories...
# Generating images...
# Generating annotations...
# Done!

# %%
# !mv data/HRF ./
# Out:
# CHASE_DB1			     healthy_manualsegm.zip
# CHASEDB1.zip			     healthy.zip
# data				     HRF
# diabetic_retinopathy_manualsegm.zip  labels-ah.tar
# diabetic_retinopathy.zip	     labels-vk.tar
# diabetic_retinopathy.zip.1	     STARE
# glaucoma_manualsegm.zip		     stare-images.tar
# glaucoma.zip			     VOCtrainval_11-May-2012.tar

# %%
import os
os.chdir('/disk1/zzl/mmsegmentation')
# !python tools/train.py 'configs/unet/fcn_unet_s5-d16_256x256_40k_hrf.py' --gpu-ids 1
# Out:
# 2022-02-27 20:10:48,450 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce GTX 1080 Ti
# CUDA_HOME: :/disk1/zzl/cuda-10.2:/home/zzl/cuda-10.2
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.9.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.9.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.10.0
# OpenCV: 4.5.5
# MMCV: 1.3.13
# MMCV Compiler: GCC 7.3
# MMCV CUDA Compiler: 10.2
# MMSegmentation: 0.17.0+ce5fcc3
# ------------------------------------------------------------
#
# 2022-02-27 20:10:48,450 - mmseg - INFO - Distributed training: False
# 2022-02-27 20:10:48,613 - mmseg - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# model = dict(
#     type='EncoderDecoder',
#     pretrained=None,
#     backbone=dict(
#         type='UNet',
#         in_channels=3,
#         base_channels=64,
#         num_stages=5,
#         strides=(1, 1, 1, 1, 1),
#         enc_num_convs=(2, 2, 2, 2, 2),
#         dec_num_convs=(2, 2, 2, 2),
#         downsamples=(True, True, True, True),
#         enc_dilations=(1, 1, 1, 1, 1),
#         dec_dilations=(1, 1, 1, 1),
#         with_cp=False,
#         conv_cfg=None,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         act_cfg=dict(type='ReLU'),
#         upsample_cfg=dict(type='InterpConv'),
#         norm_eval=False),
#     decode_head=dict(
#         type='FCNHead',
#         in_channels=64,
#         in_index=4,
#         channels=64,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=128,
#         in_index=3,
#         channels=64,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(256, 256), stride=(170, 170)))
# dataset_type = 'HRFDataset'
# data_root = 'data/HRF'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# img_scale = (2336, 3504)
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', img_scale=(2336, 3504), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(256, 256), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(2336, 3504),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=8,
#     train=dict(
#         type='RepeatDataset',
#         times=40000,
#         dataset=dict(
#             type='HRFDataset',
#             data_root='data/HRF',
#             img_dir='images/training',
#             ann_dir='annotations/training',
#             pipeline=[
#                 dict(type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations'),
#                 dict(
#                     type='Resize',
#                     img_scale=(2336, 3504),
#                     ratio_range=(0.5, 2.0)),
#                 dict(
#                     type='RandomCrop',
#                     crop_size=(256, 256),
#                     cat_max_ratio=0.75),
#                 dict(type='RandomFlip', prob=0.5),
#                 dict(type='PhotoMetricDistortion'),
#                 dict(
#                     type='Normalize',
#                     mean=[123.675, 116.28, 103.53],
#                     std=[58.395, 57.12, 57.375],
#                     to_rgb=True),
#                 dict(type='Pad', size=(256, 256), pad_val=0, seg_pad_val=255),
#                 dict(type='DefaultFormatBundle'),
#                 dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#             ])),
#     val=dict(
#         type='HRFDataset',
#         data_root='data/HRF',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(2336, 3504),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='HRFDataset',
#         data_root='data/HRF',
#         img_dir='images/validation',
#         ann_dir='annotations/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(2336, 3504),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50,
#     hooks=[
#         dict(type='TextLoggerHook', by_epoch=False),
#         dict(type='TensorboardLoggerHook')
#     ])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='IterBasedRunner', max_iters=40000)
# checkpoint_config = dict(by_epoch=False, interval=4000)
# evaluation = dict(
#     interval=4000, metric=['mDice', 'mIoU', 'mFscore'], pre_eval=True)
# work_dir = './work_dirs/fcn_unet_s5-d16_256x256_40k_hrf'
# gpu_ids = [1]
#
# 2022-02-27 20:10:48,931 - mmseg - INFO - initialize UNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-02-27 20:10:49,099 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-02-27 20:10:49,100 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:147: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   warnings.warn(
# 2022-02-27 20:10:49,102 - mmseg - INFO - EncoderDecoder(
#   (backbone): UNet(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (4): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): UpConvBlock(
#         (conv_block): BasicConvBlock(
#           (convs): Sequential(
#             (0): ConvModule(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#             (1): ConvModule(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#         (upsample): InterpConv(
#           (interp_upsample): Sequential(
#             (0): Upsample()
#             (1): ConvModule(
#               (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activate): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#   (decode_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss()
#     (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss()
#     (conv_seg): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )
# 2022-02-27 20:10:49,104 - mmseg - INFO - Loaded 15 images
# 2022-02-27 20:10:52,920 - mmseg - INFO - Loaded 30 images
# 2022-02-27 20:10:52,921 - mmseg - INFO - Start running, host: zzl@ubuntu-MW51-HP0-00, work_dir: /disk1/zzl/mmsegmentation/work_dirs/fcn_unet_s5-d16_256x256_40k_hrf
# 2022-02-27 20:10:52,921 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-02-27 20:10:52,921 - mmseg - INFO - workflow: [('train', 1)], max: 40000 iters
# /home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2022-02-27 20:11:01,986 - mmseg - INFO - Iter [50/40000]	lr: 9.989e-03, eta: 1:54:44, time: 0.172, data_time: 0.019, memory: 5371, decode.loss_seg: 0.3957, decode.acc_seg: 86.1895, aux.loss_seg: 0.1677, aux.acc_seg: 86.2058, loss: 0.5634
# 2022-02-27 20:11:06,542 - mmseg - INFO - Iter [100/40000]	lr: 9.978e-03, eta: 1:27:34, time: 0.091, data_time: 0.004, memory: 5371, decode.loss_seg: 0.2921, decode.acc_seg: 89.4560, aux.loss_seg: 0.1180, aux.acc_seg: 89.0264, loss: 0.4102
# 2022-02-27 20:11:11,248 - mmseg - INFO - Iter [150/40000]	lr: 9.967e-03, eta: 1:19:06, time: 0.094, data_time: 0.004, memory: 5371, decode.loss_seg: 0.2860, decode.acc_seg: 88.5779, aux.loss_seg: 0.1132, aux.acc_seg: 88.7905, loss: 0.3992
# 2022-02-27 20:11:15,837 - mmseg - INFO - Iter [200/40000]	lr: 9.956e-03, eta: 1:14:29, time: 0.092, data_time: 0.005, memory: 5371, decode.loss_seg: 0.2651, decode.acc_seg: 89.7228, aux.loss_seg: 0.1057, aux.acc_seg: 89.9144, loss: 0.3708
# 2022-02-27 20:11:20,381 - mmseg - INFO - Iter [250/40000]	lr: 9.945e-03, eta: 1:11:35, time: 0.091, data_time: 0.005, memory: 5371, decode.loss_seg: 0.2341, decode.acc_seg: 90.9828, aux.loss_seg: 0.0929, aux.acc_seg: 91.2690, loss: 0.3270
# 2022-02-27 20:11:24,983 - mmseg - INFO - Iter [300/40000]	lr: 9.933e-03, eta: 1:09:41, time: 0.092, data_time: 0.004, memory: 5371, decode.loss_seg: 0.2744, decode.acc_seg: 89.4211, aux.loss_seg: 0.1098, aux.acc_seg: 89.4981, loss: 0.3842
# 2022-02-27 20:11:29,800 - mmseg - INFO - Iter [350/40000]	lr: 9.922e-03, eta: 1:08:46, time: 0.097, data_time: 0.005, memory: 5371, decode.loss_seg: 0.2757, decode.acc_seg: 89.3051, aux.loss_seg: 0.1113, aux.acc_seg: 89.1439, loss: 0.3869
# 2022-02-27 20:11:34,529 - mmseg - INFO - Iter [400/40000]	lr: 9.911e-03, eta: 1:07:56, time: 0.095, data_time: 0.004, memory: 5371, decode.loss_seg: 0.
data_time: 0.004, memory: 5371, decode.loss_seg: 0.1736, decode.acc_seg: 93.4826, aux.loss_seg: 0.0709, aux.acc_seg: 93.3968, loss: 0.2445
# 2022-02-27 20:17:03,601 - mmseg - INFO - Iter [3900/40000]	lr: 9.127e-03, eta: 0:57:06, time: 0.096, data_time: 0.005, memory: 5371, decode.loss_seg: 0.1748, decode.acc_seg: 93.5771, aux.loss_seg: 0.0700, aux.acc_seg: 93.6255, loss: 0.2447
# 2022-02-27 20:17:08,369 - mmseg - INFO - Iter [3950/40000]	lr: 9.116e-03, eta: 0:57:01, time: 0.096, data_time: 0.005, memory: 5371, decode.loss_seg: 0.1787, decode.acc_seg: 93.3447, aux.loss_seg: 0.0715, aux.acc_seg: 93.2106, loss: 0.2502
# 2022-02-27 20:17:13,027 - mmseg - INFO - Saving checkpoint at 4000 iterations
# 2022-02-27 20:17:13,727 - mmseg - INFO - Exp name: fcn_unet_s5-d16_256x256_40k_hrf.py
# 2022-02-27 20:17:13,727 - mmseg - INFO - Iter [4000/40000]	lr: 9.105e-03, eta: 0:57:02, time: 0.107, data_time: 0.003, memory: 5371, decode.loss_seg: 0.1848, decode.acc_seg: 93.1095, aux.loss_seg: 0.0749, aux.acc_seg: 93.1256, loss: 0.2597
# [                                                  ] 0/30, elapsed: 0s, ETA:[W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 30/30, 0.2 task/s, elapsed: 124s, ETA:     0s2022-02-27 20:19:18,197 - mmseg - INFO - per class results:
# 2022-02-27 20:19:18,198 - mmseg - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  Dice |  Acc  |  IoU  | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 88.59 | 84.38 | 79.52 | 88.59  |   93.24   | 84.38  |
# |   vessel   | 18.15 | 28.27 |  9.98 | 18.15  |   13.36   | 28.27  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 2022-02-27 20:19:18,198 - mmseg - INFO - Summary:
# 2022-02-27 20:19:18,198 - mmseg - INFO -
# +-------+-------+-------+-------+---------+------------+---------+
# |  aAcc | mDice |  mAcc |  mIoU | mFscore | mPrecision | mRecall |
# +-------+-------+-------+-------+---------+------------+---------+
# | 79.97 | 53.37 | 56.32 | 44.75 |  53.37  |    53.3    |  56.32  |
# +-------+-------+-------+-------+---------+------------+---------+
# 2022-02-27 20:19:18,199 - mmseg - INFO - Exp name: fcn_unet_s5-d16_256x256_40k_hrf.py
# 2022-02-27 20:19:18,199 - mmseg - INFO - Iter(val) [30]	aAcc: 0.7997, mDice: 0.5337, mAcc: 0.5632, mIoU: 0.4475, mFscore: 0.5337, mPrecision: 0.5330, mRecall: 0.5632, Dice.background: 0.8859, Dice.vessel: 0.1815, Acc.background: 0.8438, Acc.vessel: 0.2827, IoU.background: 0.7952, IoU.vessel: 0.0998, Fscore.background: 0.8859, Fscore.vessel: 0.1815, Precision.background: 0.9324, Precision.vessel: 0.1336, Recall.background: 0.8438, Recall.vessel: 0.2827
# 2022-02-27 20:19:22,811 - mmseg - INFO - Iter [4050/40000]	lr: 9.093e-03, eta: 1:15:21, time: 2.581, data_time: 2.492, memory: 5371, decode.loss_seg: 0.1817, decode.acc_seg: 93.0671, aux.loss_seg: 0.0712, aux.acc_seg: 93.2139, loss: 0.2530
# 2022-02-27 20:19:27,672 - mmseg - INFO - Iter [4100/40000]	lr: 9.082e-03, eta: 1:15:02, time: 0.097, data_time: 0.004, memory: 5371, decode.loss_seg: 0.1640, decode.acc_seg: 93.9793, aux.loss_seg: 0.0664, aux.acc_seg: 93.8275, loss: 0.2304
# 2022-02-27 20:19:32,477 - mmseg - INFO - Iter [4150/40000]	lr: 9.071e-03, eta: 1:14:43, time: 0.097, data_time: 0.004, memory: 5371, decode.loss_seg: 0.
data_time: 0.004, memory: 5371, decode.loss_seg: 0.1033, decode.acc_seg: 96.1036, aux.loss_seg: 0.0417, aux.acc_seg: 96.1022, loss: 0.1450
# 2022-02-27 21:32:33,345 - mmseg - INFO - Iter [39500/40000]	lr: 2.921e-04, eta: 0:01:02, time: 0.094, data_time: 0.004, memory: 5371, decode.loss_seg: 0.1038, decode.acc_seg: 96.0007, aux.loss_seg: 0.0422, aux.acc_seg: 95.9837, loss: 0.1460
# 2022-02-27 21:32:38,240 - mmseg - INFO - Iter [39550/40000]	lr: 2.748e-04, eta: 0:00:55, time: 0.097, data_time: 0.003, memory: 5371, decode.loss_seg: 0.1029, decode.acc_seg: 96.0727, aux.loss_seg: 0.0415, aux.acc_seg: 96.0293, loss: 0.1444
# 2022-02-27 21:32:43,307 - mmseg - INFO - Iter [39600/40000]	lr: 2.573e-04, eta: 0:00:49, time: 0.101, data_time: 0.006, memory: 5371, decode.loss_seg: 0.0982, decode.acc_seg: 96.0848, aux.loss_seg: 0.0395, aux.acc_seg: 96.1015, loss: 0.1377
# 2022-02-27 21:32:48,101 - mmseg - INFO - Iter [39650/40000]	lr: 2.395e-04, eta: 0:00:43, time: 0.096, data_time: 0.004, memory: 5371, decode.loss_seg: 0.0965, decode.acc_seg: 96.1530, aux.loss_seg: 0.0392, aux.acc_seg: 96.1386, loss: 0.1357
# 2022-02-27 21:32:52,666 - mmseg - INFO - Iter [39700/40000]	lr: 2.215e-04, eta: 0:00:37, time: 0.092, data_time: 0.004, memory: 5371, decode.loss_seg: 0.1022, decode.acc_seg: 95.9738, aux.loss_seg: 0.0411, aux.acc_seg: 95.9614, loss: 0.1433
# 2022-02-27 21:32:57,470 - mmseg - INFO - Iter [39750/40000]	lr: 2.032e-04, eta: 0:00:30, time: 0.096, data_time: 0.004, memory: 5371, decode.loss_seg: 0.0930, decode.acc_seg: 96.4876, aux.loss_seg: 0.0378, aux.acc_seg: 96.4872, loss: 0.1308
# 2022-02-27 21:33:02,052 - mmseg - INFO - Iter [39800/40000]	lr: 1.845e-04, eta: 0:00:24, time: 0.092, data_time: 0.004, memory: 5371, decode.loss_seg: 0.1134, decode.acc_seg: 95.7771, aux.loss_seg: 0.0453, aux.acc_seg: 95.7796, loss: 0.1587
# 2022-02-27 21:33:06,777 - mmseg - INFO - Iter [39850/40000]	lr: 1.653e-04, eta: 0:00:18, time: 0.095, data_time: 0.006, memory: 5371, decode.loss_seg: 0.1055, decode.acc_seg: 95.9552, aux.loss_seg: 0.0421, aux.acc_seg: 95.9791, loss: 0.1476
# 2022-02-27 21:33:11,520 - mmseg - INFO - Iter [39900/40000]	lr: 1.455e-04, eta: 0:00:12, time: 0.095, data_time: 0.005, memory: 5371, decode.loss_seg: 0.1066, decode.acc_seg: 95.8117, aux.loss_seg: 0.0431, aux.acc_seg: 95.8044, loss: 0.1497
# 2022-02-27 21:33:16,141 - mmseg - INFO - Iter [39950/40000]	lr: 1.246e-04, eta: 0:00:06, time: 0.093, data_time: 0.005, memory: 5371, decode.loss_seg: 0.1022, decode.acc_seg: 95.9417, aux.loss_seg: 0.0415, aux.acc_seg: 95.9045, loss: 0.1437
# 2022-02-27 21:33:20,786 - mmseg - INFO - Saving checkpoint at 40000 iterations
# 2022-02-27 21:33:21,684 - mmseg - INFO - Exp name: fcn_unet_s5-d16_256x256_40k_hrf.py
# 2022-02-27 21:33:21,684 - mmseg - INFO - Iter [40000/40000]	lr: 1.007e-04, eta: 0:00:00, time: 0.111, data_time: 0.003, memory: 5371, decode.loss_seg: 0.1031, decode.acc_seg: 95.9394, aux.loss_seg: 0.0418, aux.acc_seg: 95.9489, loss: 0.1449
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 30/30, 0.2 task/s, elapsed: 127s, ETA:     0s2022-02-27 21:35:28,486 - mmseg - INFO - per class results:
# 2022-02-27 21:35:28,486 - mmseg - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  Dice |  Acc  |  IoU  | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 98.16 | 99.37 | 96.38 | 98.16  |   96.97   | 99.37  |
# |   vessel   | 74.38 | 63.56 | 59.21 | 74.38  |   89.63   | 63.56  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 2022-02-27 21:35:28,486 - mmseg - INFO - Summary:
# 2022-02-27 21:35:28,487 - mmseg - INFO -
# +-------+-------+-------+------+---------+------------+---------+
# |  aAcc | mDice |  mAcc | mIoU | mFscore | mPrecision | mRecall |
# +-------+-------+-------+------+---------+------------+---------+
# | 96.56 | 86.27 | 81.47 | 77.8 |  86.27  |    93.3    |  81.47  |
# +-------+-------+-------+------+---------+------------+---------+
# 2022-02-27 21:35:28,487 - mmseg - INFO - Exp name: fcn_unet_s5-d16_256x256_40k_hrf.py
# 2022-02-27 21:35:28,487 - mmseg - INFO - Iter(val) [30]	aAcc: 0.9656, mDice: 0.8627, mAcc: 0.8147, mIoU: 0.7780, mFscore: 0.8627, mPrecision: 0.9330, mRecall: 0.8147, Dice.background: 0.9816, Dice.vessel: 0.7438, Acc.background: 0.9937, Acc.vessel: 0.6356, IoU.background: 0.9638, IoU.vessel: 0.5921, Fscore.background: 0.9816, Fscore.vessel: 0.7438, Precision.background: 0.9697, Precision.vessel: 0.8963, Recall.background: 0.9937, Recall.vessel: 0.6356

# %%
# !python tools/test.py 'configs/unet/fcn_unet_s5-d16_256x256_40k_hrf.py' 'work_dirs/fcn_unet_s5-d16_256x256_40k_hrf/iter_36000.pth' --eval 'auc'
# Out:
# 2022-02-28 16:16:00,439 - mmseg - INFO - Loaded 30 images
# Use load_from_local loader
# [                                                  ] 0/30, elapsed: 0s, ETA:/home/zzl/.conda/envs/zzl1/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 30/30, 0.1 task/s, elapsed: 211s, ETA:     0sper class results:
#
# +------------+---------+
# |   Class    |   auc   |
# +------------+---------+
# | background |   0.0   |
# |   vessel   | 0.98198 |
# +------------+---------+
# Summary:
#
# +---------+
# |   mauc  |
# +---------+
# | 0.98198 |
# +---------+
